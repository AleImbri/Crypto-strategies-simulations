# %%
import ccxt
import pandas as pd
import random
import time
from datetime import datetime, timedelta

random.seed(8)

# %%
# Configurazione
symbol = 'BTC/USDT'
timeframe = '1m'
exchange_id = 'bybit'
start_date = datetime(2021, 1, 9)
end_date = datetime(2023, 12, 3)
period_minutes = 24 * 60
num_columns = 100
output_file = '100_datasets_1440_minutes_random_state_8_bybit_period_9_jan_2021_3_dic_2023.csv'

# Inizializza l'exchange
print("Inizializzazione dell'exchange...")
exchange = getattr(ccxt, exchange_id)({'enableRateLimit': True})
print("Exchange inizializzato con successo.")

# Funzione per scaricare i dati in blocchi
def fetch_data_blocks(symbol, timeframe, start, end):
    print(f"Scarico i dati da {start} a {end}...")
    data = []
    since = int(start.timestamp() * 1000)
    end_timestamp = int(end.timestamp() * 1000)

    while since < end_timestamp:
        try:
            ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since)
            if not ohlcv:
                print("Nessun dato restituito. Uscita dal ciclo fetch.")
                break
            data += ohlcv
            since = ohlcv[-1][0] + 1  # Avanza al prossimo blocco
            time.sleep(exchange.rateLimit / 1000)  # Rispetta il rate limit
        except Exception as e:
            print(f"Errore durante il fetch: {e}")
            break

    return data

# Genera un periodo casuale valido senza duplicati
def generate_valid_period(existing_periods):
    max_start_minutes = int((end_date - start_date).total_seconds() // 60) - period_minutes
    while True:
        random_start = start_date + timedelta(minutes=random.randint(0, max_start_minutes))
        random_end = random_start + timedelta(minutes=period_minutes)
        if any(random_start == p[0] and random_end == p[1] for p in existing_periods):
            print(f"Periodo duplicato {random_start} - {random_end}. Genero un nuovo periodo...")
            continue
        raw_data = fetch_data_blocks(symbol, timeframe, random_start, random_end)
        if raw_data and len(raw_data) >= period_minutes:  # Verifica se i dati sono completi
            return random_start, random_end, raw_data
        print(f"Dati insufficienti o assenti per il periodo {random_start} - {random_end}. Genero un nuovo periodo...")

# Crea il DataFrame finale
print("Creazione del DataFrame finale...")
data = pd.DataFrame()
data['Timestamp'] = [start_date + timedelta(minutes=i) for i in range(period_minutes)]
data['Timestamp'] = data['Timestamp'].apply(lambda x: exchange.iso8601(int(x.timestamp() * 1000))) # Timestamp formato ccxt
print("Colonna Timestamp creata con successo.")

existing_periods = []
for i in range(num_columns):
    print(f"Elaborazione del periodo {i + 1}/{num_columns}...")
    start, end, raw_data = generate_valid_period(existing_periods)
    existing_periods.append((start, end))

    df = pd.DataFrame(raw_data, columns=['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume'])
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='ms')
    df.set_index('Timestamp', inplace=True)

    data[f'Price_{i + 1}'] = df['Close'].values[:period_minutes]
    print(f"Colonna Price_{i + 1} aggiunta con successo.")

# Esporta in CSV
print("Esportazione dei dati in CSV...")
data.to_csv(output_file, index=False)
print(f"Dati salvati in {output_file}")
# Out:
# Inizializzazione dell'exchange...
# Exchange inizializzato con successo.
# Creazione del DataFrame finale...
# Colonna Timestamp creata con successo.
# Elaborazione del periodo 1/100...
# Scarico i dati da 2021-12-05 03:56:00 a 2021-12-06 03:56:00...
# Colonna Price_1 aggiunta con successo.
# Elaborazione del periodo 2/100...
# Scarico i dati da 2022-07-02 10:49:00 a 2022-07-03 10:49:00...
# Colonna Price_2 aggiunta con successo.
# Elaborazione del periodo 3/100...
# Scarico i dati da 2022-07-09 16:06:00 a 2022-07-10 16:06:00...
# Colonna Price_3 aggiunta con successo.
# Elaborazione del periodo 4/100...
# Scarico i dati da 2021-07-11 23:35:00 a 2021-07-12 23:35:00...
# Colonna Price_4 aggiunta con successo.
# Elaborazione del periodo 5/100...
# Scarico i dati da 2021-10-17 05:54:00 a 2021-10-18 05:54:00...
# Colonna Price_5 aggiunta con successo.
# Elaborazione del periodo 6/100...
# Scarico i dati da 2023-11-01 11:08:00 a 2023-11-02 11:08:00...
# Colonna Price_6 aggiunta con successo.
# Elaborazione del periodo 7/100...
# Scarico i dati da 2021-03-13 18:10:00 a 2021-03-14 18:10:00...
# Nessun dato restituito. Uscita dal ciclo fetch.
# Dati insufficienti o assenti per il periodo 2021-03-13 18:10:00 - 2021-03-14 18:10:00. Genero un nuovo periodo...
# Scarico i dati da 2021-05-13 01:26:00 a 2021-05-14 01:26:00...
# Nessun dato restituito. Uscita dal ciclo fetch.
# Dati insufficienti o assenti per il periodo 2021-05-13 01:26:00 - 2021-05-14 01:26:00. Genero un nuovo periodo...
# Scarico i dati da 2021-07-27 07:00:00 a 2021-07-28 07:00:00...
# Colonna Price_7 aggiunta con successo.
# Elaborazione del periodo 8/100...
# Scarico i dati da 2022-01-04 08:41:00 a 2022-01-05 08:41:00...
# Colonna Price_8 aggiunta con successo.
# Elaborazione del periodo 9/100...
# Scarico i dati da 2023-01-16 10:34:00 a 2023-01-17 10:34:00...
# Colonna Price_9 aggiunta con successo.
# Elaborazione del periodo 10/100...
# Scarico i dati da 2021-11-09 22:58:00 a 2021-11-10 22:58:00...
# Colonna Price_10 aggiunta con successo.
# Elaborazione del periodo 11/100...
# Scarico i dati da 2022-08-15 13:50:00 a 2022-08-16 13:50:00...
# Colonna Price_11 aggiunta con successo.
# Elaborazione del periodo 12/100...
# Scarico i dati da 2023-08-01 18:55:00 a 2023-08-02 18:55:00...
# Colonna Price_12 aggiunta con successo.
# Elaborazione del periodo 13/100...
# Scarico i dati da 2021-02-22 02:50:00 a 2021-02-23 02:50:00...
# Nessun dato restituito. Uscita dal ciclo fetch.
# Dati insufficienti o assenti per il periodo 2021-02-22 02:50:00 - 2021-02-23 02:50:00. Genero un nuovo periodo...
# Scarico i dati da 2022-11-08 15:53:00 a 2022-11-09 15:53:00...
# Colonna Price_13 aggiunta con successo.
# Elaborazione del periodo 14/100...
# Scarico i dati da 2022-12-19 19:56:00 a 2022-12-20 19:56:00...
# Colonna Price_14 aggiunta con successo.
# Elaborazione del periodo 15/100...
# Scarico i dati da 2022-10-30 22:07:00 a 2022-10-31 22:07:00...
# Colonna Price_15 aggiunta con successo.
# Elaborazione del periodo 16/100...
# Scarico i dati da 2022-07-31 16:11:00 a 2022-08-01 16:11:00...
# Colonna Price_16 aggiunta con successo.
# Elaborazione del periodo 17/100...
# Scarico i dati da 2022-12-30 20:53:00 a 2022-12-31 20:53:00...
# Colonna Price_17 aggiunta con successo.
# Elaborazione del periodo 18/100...
# Scarico i dati da 2023-04-23 16:10:00 a 2023-04-24 16:10:00...
# Colonna Price_18 aggiunta con successo.
# Scarico i dati da 2021-08-12 20:14:00 a 2021-08-13 20:14:00...
# Colonna Price_49 aggiunta con successo.
# Elaborazione del periodo 50/100...
# Scarico i dati da 2023-05-02 04:10:00 a 2023-05-03 04:10:00...
# Colonna Price_50 aggiunta con successo.
# Elaborazione del periodo 51/100...
# Scarico i dati da 2022-11-04 11:33:00 a 2022-11-05 11:33:00...
# Colonna Price_51 aggiunta con successo.
# Elaborazione del periodo 52/100...
# Scarico i dati da 2023-05-10 01:05:00 a 2023-05-11 01:05:00...
# Colonna Price_52 aggiunta con successo.
# Elaborazione del periodo 53/100...
# Scarico i dati da 2022-10-19 06:39:00 a 2022-10-20 06:39:00...
# Colonna Price_53 aggiunta con successo.
# Elaborazione del periodo 54/100...
# Scarico i dati da 2022-03-01 00:18:00 a 2022-03-02 00:18:00...
# Colonna Price_54 aggiunta con successo.
# Elaborazione del periodo 55/100...
# Scarico i dati da 2023-03-31 15:44:00 a 2023-04-01 15:44:00...
# Colonna Price_55 aggiunta con successo.
# Elaborazione del periodo 56/100...
# Scarico i dati da 2022-06-12 11:27:00 a 2022-06-13 11:27:00...
# Colonna Price_56 aggiunta con successo.
# Elaborazione del periodo 57/100...
# Scarico i dati da 2022-09-21 13:58:00 a 2022-09-22 13:58:00...
# Colonna Price_57 aggiunta con successo.
# Elaborazione del periodo 58/100...
# Scarico i dati da 2021-07-24 13:44:00 a 2021-07-25 13:44:00...
# Colonna Price_58 aggiunta con successo.
# Elaborazione del periodo 59/100...
# Scarico i dati da 2021-08-27 12:58:00 a 2021-08-28 12:58:00...
# Colonna Price_59 aggiunta con successo.
# Elaborazione del periodo 60/100...
# Scarico i dati da 2023-06-03 17:22:00 a 2023-06-04 17:22:00...
# Colonna Price_60 aggiunta con successo.
# Elaborazione del periodo 61/100...
# Scarico i dati da 2021-05-31 03:56:00 a 2021-06-01 03:56:00...
# Nessun dato restituito. Uscita dal ciclo fetch.
# Dati insufficienti o assenti per il periodo 2021-05-31 03:56:00 - 2021-06-01 03:56:00. Genero un nuovo periodo...
# Scarico i dati da 2023-02-22 12:02:00 a 2023-02-23 12:02:00...
# Colonna Price_61 aggiunta con successo.
# Elaborazione del periodo 62/100...
# Scarico i dati da 2023-10-11 03:35:00 a 2023-10-12 03:35:00...
# Colonna Price_62 aggiunta con successo.
# Elaborazione del periodo 63/100...
# Scarico i dati da 2022-04-10 23:38:00 a 2022-04-11 23:38:00...
# Colonna Price_63 aggiunta con successo.
# Elaborazione del periodo 64/100...
# Scarico i dati da 2023-10-28 13:45:00 a 2023-10-29 13:45:00...
# Colonna Price_64 aggiunta con successo.
# Elaborazione del periodo 65/100...
# Scarico i dati da 2022-06-12 23:07:00 a 2022-06-13 23:07:00...
# Colonna Price_65 aggiunta con successo.
# Elaborazione del periodo 66/100...
# Scarico i dati da 2023-08-04 18:09:00 a 2023-08-05 18:09:00...
# Colonna Price_66 aggiunta con successo.
# Elaborazione del periodo 67/100...
# Scarico i dati da 2022-12-30 08:38:00 a 2022-12-31 08:38:00...
# Colonna Price_67 aggiunta con successo.
# Elaborazione del periodo 68/100...
# Scarico i dati da 2023-01-12 10:50:00 a 2023-01-13 10:50:00...
# Colonna Price_68 aggiunta con successo.
# Elaborazione del periodo 69/100...
# Scarico i dati da 2023-07-06 17:52:00 a 2023-07-07 17:52:00...
# Colonna Price_69 aggiunta con successo.
# Elaborazione del periodo 70/100...
# Scarico i dati da 2021-10-23 20:18:00 a 2021-10-24 20:18:00...
# Colonna Price_70 aggiunta con successo.
# Elaborazione del periodo 71/100...
# Scarico i dati da 2022-04-03 17:02:00 a 2022-04-04 17:02:00...
# Colonna Price_71 aggiunta con successo.
# Elaborazione del periodo 72/100...
# Scarico i dati da 2021-08-15 16:28:00 a 2021-08-16 16:28:00...
# Colonna Price_72 aggiunta con successo.
# Elaborazione del periodo 73/100...
# Scarico i dati da 2022-06-11 01:58:00 a 2022-06-12 01:58:00...
# Colonna Price_73 aggiunta con successo.
# Elaborazione del periodo 74/100...
# Scarico i dati da 2023-02-18 00:06:00 a 2023-02-19 00:06:00...
# Colonna Price_74 aggiunta con successo.
# Elaborazione del periodo 75/100...
# Scarico i dati da 2022-02-27 02:54:00 a 2022-02-28 02:54:00...
# Colonna Price_75 aggiunta con successo.
# Elaborazione del periodo 76/100...
# Scarico i dati da 2023-01-21 10:28:00 a 2023-01-22 10:28:00...
# Colonna Price_76 aggiunta con successo.
# Elaborazione del periodo 77/100...
# Scarico i dati da 2023-08-23 21:46:00 a 2023-08-24 21:46:00...
# Colonna Price_77 aggiunta con successo.
# Elaborazione del periodo 78/100...
# Scarico i dati da 2021-04-23 00:20:00 a 2021-04-24 00:20:00...
# Nessun dato restituito. Uscita dal ciclo fetch.
# Dati insufficienti o assenti per il periodo 2021-04-23 00:20:00 - 2021-04-24 00:20:00. Genero un nuovo periodo...
# Scarico i dati da 2023-01-17 23:31:00 a 2023-01-18 23:31:00...
# Colonna Price_78 aggiunta con successo.
# Elaborazione del periodo 79/100...
# Scarico i dati da 2023-10-27 08:01:00 a 2023-10-28 08:01:00...
# Colonna Price_79 aggiunta con successo.
# Elaborazione del periodo 80/100...
# Scarico i dati da 2023-03-13 14:53:00 a 2023-03-14 14:53:00...
# Colonna Price_80 aggiunta con successo.
# Elaborazione del periodo 81/100...
# Scarico i dati da 2021-11-25 07:59:00 a 2021-11-26 07:59:00...
# Colonna Price_81 aggiunta con successo.
# Elaborazione del periodo 82/100...
# Scarico i dati da 2022-05-25 06:44:00 a 2022-05-26 06:44:00...
# Colonna Price_82 aggiunta con successo.
# Elaborazione del periodo 83/100...
# Scarico i dati da 2021-12-30 04:26:00 a 2021-12-31 04:26:00...
# Colonna Price_83 aggiunta con successo.
# Elaborazione del periodo 84/100...
# Scarico i dati da 2021-01-26 08:30:00 a 2021-01-27 08:30:00...
# Nessun dato restituito. Uscita dal ciclo fetch.
# Dati insufficienti o assenti per il periodo 2021-01-26 08:30:00 - 2021-01-27 08:30:00. Genero un nuovo periodo...
# Scarico i dati da 2022-03-15 15:41:00 a 2022-03-16 15:41:00...
# Colonna Price_84 aggiunta con successo.
# Elaborazione del periodo 85/100...
# Scarico i dati da 2022-05-23 20:48:00 a 2022-05-24 20:48:00...
# Colonna Price_85 aggiunta con successo.
# Elaborazione del periodo 86/100...
# Scarico i dati da 2021-11-25 02:15:00 a 2021-11-26 02:15:00...
# Colonna Price_86 aggiunta con successo.
# Elaborazione del periodo 87/100...
# Scarico i dati da 2022-02-01 14:48:00 a 2022-02-02 14:48:00...
# Colonna Price_87 aggiunta con successo.
# Elaborazione del periodo 88/100...
# Scarico i dati da 2021-02-27 00:16:00 a 2021-02-28 00:16:00...
# Nessun dato restituito. Uscita dal ciclo fetch.
# Dati insufficienti o assenti per il periodo 2021